# %%
from PIL import Image
path = "oscar.png"
display(Image.open(path))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=433x577>

# %% [markdown]
# Projet 1:
#
# Dans ce projet j'ai réalisé une application web pour évaluer le risque du crédit à l'aide de l'apprentissage automatique

# %%
from warnings import filterwarnings
filterwarnings('ignore')
from IPython.display import HTML

# %%
HTML('<iframe src="https://oscarhouessou.shinyapps.io/credit_scoring/" width= "950" height= "800"  frameborder ="0" ></frame>')
# Out:
# <iframe src="https://oscarhouessou.shinyapps.io/credit_scoring/" width= "950" height= "800"  frameborder ="0" ></frame>

# %% [markdown]
# Lien vers mon application : https://oscarhouessou.shinyapps.io/credit_scoring/

# %% [markdown]
# Projet 2:  Application pour analyser les données de Airbnb

# %%
#<img src="airbnb_dashboard.png" alt="Airbnb dashbord" />
path2 ="airbnb_dashboard.png"
display(Image.open(path2))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1338x505>

# %% [markdown]
# Lien vers mon application : https://public.tableau.com/views/airbnb_tableau_16617069695470/TableaudebordDonneAirbnb?:language=en-US&:display_count=n&:origin=viz_share_link
